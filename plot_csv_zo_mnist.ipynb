# %%
import numpy as np
import matplotlib.pyplot as plt
import os
print(os.getcwd())
# Out:
# /home/dai/shao/optimisationpy

# %%
file = open("experiment_results/MNIST_PN_solvers.zo.ada_exp_grad_0.5000/average_loss.csv")
adaexpmdpn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.ada_exp_grad_p_0.5000/average_loss.csv")
adaexpmdppn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.ada_exp_grad_vr_0.5000/average_loss.csv")
expstormpn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.ao_exp_grad_1.0000/average_loss.csv")
aoexpmdpn = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), adaexpmdpn,label=r'ZO-AdaExpGrad', marker='v',markevery=10)
ax.plot(range(0,201), adaexpmdppn,label=r'ZO-AdaExpGradP', marker='o',markevery=10)
ax.plot(range(0,201), expstormpn,label=r'ZO-ExpStorm', marker='s',markevery=10)
ax.plot(range(0,201), aoexpmdpn,label=r'AO_ExpMD', marker='^',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/MNIST_PN_solvers.zo.pgd_1.0000/average_loss.csv")
pgd1pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.pgd_0.1000/average_loss.csv")
pgd2pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.pgd_0.0100/average_loss.csv")
pgd3pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.pgd_0.0010/average_loss.csv")
pgd4pn = np.loadtxt(file, delimiter=",")
#file = open("experiment_results/MNIST_PN_solvers.zo.pgd_0.0001/average_loss.csv")
#pgd5pn = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), pgd1pn,label=r'ZO-PSGD $\eta=1$', marker='v',markevery=10)
ax.plot(range(0,201), pgd2pn,label=r'ZO-PSGD $\eta=10$', marker='^',markevery=10)
ax.plot(range(0,201), pgd3pn,label=r'ZO-PSGD $\eta=10^2$', marker='o',markevery=10)
ax.plot(range(0,201), pgd4pn,label=r'ZO-PSGD $\eta=10^3$', marker='s',markevery=10)
#ax.plot(range(0,201), pgd5pn,label=r'ZO-PSGD $\eta=10^4$', marker='d',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pgd_pn_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_1.0000/average_loss.csv")
exp_grad1pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_0.1000/average_loss.csv")
exp_grad2pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_0.0100/average_loss.csv")
exp_grad3pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_0.0010/average_loss.csv")
exp_grad4pn = np.loadtxt(file, delimiter=",")
#file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_0.0001/average_loss.csv")
#exp_grad5pn = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), exp_grad1pn,label=r'ZO-ExpGrad $\eta=1$', marker='v',markevery=10)
ax.plot(range(0,201), exp_grad2pn,label=r'ZO-ExpGrad $\eta=10$', marker='^',markevery=10)
ax.plot(range(0,201), exp_grad3pn,label=r'ZO-ExpGrad $\eta=10^2$', marker='o',markevery=10)
ax.plot(range(0,201), exp_grad4pn,label=r'ZO-ExpGrad $\eta=10^3$', marker='s',markevery=10)
#ax.plot(range(0,201), exp_grad5pn,label=r'ZO-ExpMD $\eta=10^4$', marker='d',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_exp_pn_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
file = open("experiment_results/MNIST_PN_solvers.zo.ada_pgd_vr_1.0000/average_loss.csv")
pgdvr1pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.ada_pgd_vr_0.1000/average_loss.csv")
pgdvr2pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.ada_pgd_vr_0.0100/average_loss.csv")
pgdvr3pn = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PN_solvers.zo.ada_pgd_vr_0.0010/average_loss.csv")
pgdvr4pn = np.loadtxt(file, delimiter=",")
#file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_0.0001/average_loss.csv")
#exp_grad5pn = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), pgdvr1pn,label=r'Acc-ZOM $\gamma=1$', marker='v',markevery=10)
ax.plot(range(0,201), pgdvr2pn,label=r'Acc-ZOM $\gamma=0.1$', marker='^',markevery=10)
ax.plot(range(0,201), pgdvr3pn,label=r'Acc-ZOM $\gamma=0.01$', marker='o',markevery=10)
ax.plot(range(0,201), pgdvr4pn,label=r'Acc-ZOM $\gamma=0.001$', marker='s',markevery=10)
#ax.plot(range(0,201), exp_grad5pn,label=r'ZO-ExpMD $\eta=10^4$', marker='d',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_zom_pn_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), pgd2pn,label=r'ZO-PSGD', marker='v',markevery=10)
ax.plot(range(0,201), pgdvr1pn,label=r'Acc-ZOM', marker='^',markevery=10)
ax.plot(range(0,201), aoexpmdpn,label=r'AO-ExpMD', marker='o',markevery=10)
ax.plot(range(0,201), exp_grad1pn,label=r'ZO-ExpGrad', marker='d',markevery=10)
ax.plot(range(0,201), adaexpmdpn,label=r'ZO-AdaExpGrad', marker='s',markevery=10)
ax.plot(range(0,201), adaexpmdppn,label=r'ZO-AdaExpGrad$+$', marker='1',markevery=10)
ax.plot(range(0,201), expstormpn,label=r'ZO-ExpStorm', marker='2',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pn_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), adaexpmdpn,label=r'ZO-AdaExpGrad', marker='^',markevery=10)
ax.plot(range(0,201), adaexpmdppn,label=r'ZO-AdaExpGrad$+$', marker='s',markevery=10)
ax.plot(range(0,201), expstormpn,label=r'ZO-ExpStorm', marker='d',markevery=10)
plt.xlim(100, 200)
plt.ylim(5.2e-2, 5.5e-2)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pn_mnist_last.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), adaexpmdpn,label=r'ZO-AdaExpGrad', marker='^',markevery=1)
ax.plot(range(0,201), adaexpmdppn,label=r'ZO-AdaExpGrad$+$', marker='s',markevery=1)
ax.plot(range(0,201), expstormpn,label=r'ZO-ExpStorm', marker='d',markevery=1)
plt.xlim(25, 30)
plt.ylim(1.4e-1, 1.75e-1)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pn_mnist_first.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
file = open("experiment_results/MNIST_PP_solvers.zo.ada_exp_grad_0.5000/average_loss.csv")
adaexpmdpp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.ada_exp_grad_p_0.5000/average_loss.csv")
adaexpmdppp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.ada_exp_grad_vr_0.5000/average_loss.csv")
expstormpp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.ao_exp_grad_1.0000/average_loss.csv")
aoexpmdpp = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), adaexpmdpp,label=r'ZO-AdaExpGrad', marker='v',markevery=10)
ax.plot(range(0,201), adaexpmdppp,label=r'ZO-AdaExpGrad$+$', marker='o',markevery=10)
ax.plot(range(0,201), expstormpp,label=r'ZO-ExpStorm', marker='s',markevery=10)
ax.plot(range(0,201), aoexpmdpp,label=r'AO-ExpMD', marker='^',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/MNIST_PP_solvers.zo.pgd_1.0000/average_loss.csv")
pgd1pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.pgd_0.1000/average_loss.csv")
pgd2pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.pgd_0.0100/average_loss.csv")
pgd3pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.pgd_0.0010/average_loss.csv")
pgd4pp = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), pgd1pp,label=r'ZO-PSGD $\eta=1$', marker='v',markevery=10)
ax.plot(range(0,201), pgd2pp,label=r'ZO-PSGD $\eta=10$', marker='^',markevery=10)
ax.plot(range(0,201), pgd3pp,label=r'ZO-PSGD $\eta=10^2$', marker='o',markevery=10)
ax.plot(range(0,201), pgd4pp,label=r'ZO-PSGD $\eta=10^3$', marker='s',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pgd_pp_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
file = open("experiment_results/MNIST_PP_solvers.zo.exp_grad_1.0000/average_loss.csv")
exp_grad1pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.exp_grad_0.1000/average_loss.csv")
exp_grad2pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.exp_grad_0.0100/average_loss.csv")
exp_grad3pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.exp_grad_0.0010/average_loss.csv")
exp_grad4pp = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), exp_grad1pp,label=r'ZO-ExpGrad $\eta=1$', marker='v',markevery=10)
ax.plot(range(0,201), exp_grad2pp,label=r'ZO-ExpGrad $\eta=10$', marker='^',markevery=10)
ax.plot(range(0,201), exp_grad3pp,label=r'ZO-ExpGrad $\eta=10^2$', marker='o',markevery=10)
ax.plot(range(0,201), exp_grad4pp,label=r'ZO-ExpGrad $\eta=10^3$', marker='s',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_exp_pp_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
file = open("experiment_results/MNIST_PP_solvers.zo.ada_pgd_vr_1.0000/average_loss.csv")
pgdvr1pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.ada_pgd_vr_0.1000/average_loss.csv")
pgdvr2pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.ada_pgd_vr_0.0100/average_loss.csv")
pgdvr3pp = np.loadtxt(file, delimiter=",")
file = open("experiment_results/MNIST_PP_solvers.zo.ada_pgd_vr_0.0010/average_loss.csv")
pgdvr4pp = np.loadtxt(file, delimiter=",")
#file = open("experiment_results/MNIST_PN_solvers.zo.exp_grad_0.0001/average_loss.csv")
#exp_grad5pn = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), pgdvr1pp,label=r'Acc-ZOM $\gamma=1$', marker='v',markevery=10)
ax.plot(range(0,201), pgdvr2pp,label=r'Acc-ZOM $\gamma=0.1$', marker='^',markevery=10)
ax.plot(range(0,201), pgdvr3pp,label=r'Acc-ZOM $\gamma=0.01$', marker='o',markevery=10)
ax.plot(range(0,201), pgdvr4pp,label=r'Acc-ZOM $\gamma=0.001$', marker='s',markevery=10)
#ax.plot(range(0,201), exp_grad5pn,label=r'ZO-ExpMD $\eta=10^4$', marker='d',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_zom_pp_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), pgd2pp,label=r'ZO-PSGD', marker='v',markevery=10)
ax.plot(range(0,201), pgdvr1pp,label=r'Acc-ZOM', marker='^',markevery=10)
ax.plot(range(0,201), aoexpmdpp,label=r'AO-ExpMD', marker='o',markevery=10)
ax.plot(range(0,201), exp_grad1pp,label=r'ZO-ExpGrad', marker='d',markevery=10)
ax.plot(range(0,201), adaexpmdpp,label=r'ZO-AdaExpGrad', marker='s',markevery=10)
ax.plot(range(0,201), adaexpmdppp,label=r'ZO-AdaExpGrad$+$', marker='1',markevery=10)
ax.plot(range(0,201), expstormpp,label=r'ZO-ExpStorm', marker='2',markevery=10)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pp_mnist.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), adaexpmdpp,label=r'ZO-AdaExpGrad', marker='^',markevery=1)
ax.plot(range(0,201), adaexpmdppp,label=r'ZO-AdaExpGrad$+$', marker='s',markevery=1)
ax.plot(range(0,201), expstormpp,label=r'ZO-ExpStorm', marker='d',markevery=1)
plt.xlim(190, 200)
plt.ylim(8e-2,8.2e-2)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pp_mnist_last.pdf', format="pdf", bbox_inches="tight")  
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(range(0,201), adaexpmdpp,label=r'ZO-AdaExpGrad', marker='^',markevery=1)
ax.plot(range(0,201), adaexpmdppp,label=r'ZO-AdaExpGrad$+$', marker='s',markevery=1)
ax.plot(range(0,201), expstormpp,label=r'ZO-ExpStorm', marker='d',markevery=1)
plt.xlim(25, 30)
plt.ylim(1.3e-1, 1.52e-1)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.savefig('zo_pp_mnist_first.pdf', format="pdf", bbox_inches="tight")  
plt.show()
